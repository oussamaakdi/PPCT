# %% [markdown]
# <a href="https://colab.research.google.com/github/oussamaakdi/PPCT/blob/main/yfinance/yfinance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install yfinance

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# Télécharger les données d'Apple pour l'année 2023
data = yf.download("AAPL", start="2023-01-01", end="2023-12-31")

# Afficher les premières lignes
print(data.head())

# Visualiser le prix de clôture
plt.figure(figsize=(10, 6))
plt.plot(data.index, data['Close'], label="Prix de Clôture", color='blue')
plt.title("Évolution du prix d'Apple (AAPL) en 2023")
plt.xlabel("Date")
plt.ylabel("Prix (USD)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Adj Close       Close        High         Low  \
# Ticker                           AAPL        AAPL        AAPL        AAPL
# Date
# 2023-01-03 00:00:00+00:00  123.768463  125.070000  130.899994  124.169998
# 2023-01-04 00:00:00+00:00  125.045044  126.360001  128.660004  125.080002
# 2023-01-05 00:00:00+00:00  123.718979  125.019997  127.769997  124.760002
# 2023-01-06 00:00:00+00:00  128.271103  129.619995  130.289993  124.889999
# 2023-01-09 00:00:00+00:00  128.795609  130.149994  133.410004  129.889999
#
# Price                            Open     Volume
# Ticker                           AAPL       AAPL
# Date
# 2023-01-03 00:00:00+00:00  130.279999  112117500
# 2023-01-04 00:00:00+00:00  126.889999   89113600
# 2023-01-05 00:00:00+00:00  127.129997   80962700
# 2023-01-06 00:00:00+00:00  126.010002   87754700
# 2023-01-09 00:00:00+00:00  130.470001   70790800
